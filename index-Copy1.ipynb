# %% [markdown]
# ### Exercise 1
#
# <div class="alert-success">
#
# 1. **Use two maps of points.**
#
# 2. **Compute the distance matrix for both maps.**
#
# 3. **Select one row of the distance matrix, and plot the two points with the minimal distance on top of the country of your choosing.**
# </div>

# %%
from  fiona import listlayers
import os

argentinaMaps=os.path.join('maps','argentina22171','argentinaMaps22171_all3.gpkg')

#layers in maps
listlayers(argentinaMaps)
# Out:
# ['country',
#  'cities',
#  'rivers',
#  'states',
#  'municipalities',
#  'border',
#  'airports']

# %%
# reading in the data:
import os
import geopandas as gpd

country=gpd.read_file(argentinaMaps,layer='country')
states=gpd.read_file(argentinaMaps,layer='states')
municipalities=gpd.read_file(argentinaMaps,layer='municipalities')
airports=gpd.read_file(argentinaMaps,layer='airports')
rivers=gpd.read_file(argentinaMaps,layer='rivers')
border=gpd.read_file(argentinaMaps,layer='border')

# %%
medium_airport=airports[airports['type']=='medium_airport'] #can't use "airports.type"
medium_airport.reset_index(drop=True, inplace=True)
medium_airport
# Out:
#                                                  name            type  \
# 0                         Malvinas Argentinas Airport  medium_airport
# 1   El Calafate - Commander Armando Tola Internati...  medium_airport
# 2          Cataratas Del Iguazú International Airport  medium_airport
# 3                               El Plumerillo Airport  medium_airport
# 4                     San Carlos De Bariloche Airport  medium_airport
# ..                                                ...             ...
# 63                                       Orán Airport  medium_airport
# 64                       Rincon De Los Sauces Airport  medium_airport
# 65                               Tres Arroyos Airport  medium_airport
# 66                              Villa Dolores Airport  medium_airport
# 67                                     Zapala Airport  medium_airport
#
#     latitude_deg  longitude_deg  elevation_ft                region_name  \
# 0     -54.843300     -68.295800         102.0  Tierra del Fuego Province
# 1     -50.280300     -72.053101         669.0        Santa Cruz Province
# 2     -25.737301     -54.473400         916.0          Misiones Province
# 3     -32.831699     -68.792900        2310.0           Mendoza Province
# 4     -41.151199     -71.157501        2774.0         Río Negro Province
# ..           ...            ...           ...                        ...
# 63    -23.152800     -64.329201        1171.0             Salta Province
# 64    -37.390598     -68.904198        1968.0           Neuquén Province
# 65    -38.386900     -60.329700         400.0      Buenos Aires Province
# 66    -31.945200     -65.146301        1847.0           Córdoba Province
# 67    -38.975498     -70.113602        3330.0           Neuquén Province
#
#                municipality                         geometry
# 0                   Ushuaia  POINT (1737945.839 3915824.327)
# 1               El Calafate  POINT (1496258.115 4429856.907)
# 2             Puerto Iguazu  POINT (3275864.379 7033639.587)
# 3                   Mendoza  POINT (1800378.820 6363192.739)
# 4   San Carlos de Bariloche  POINT (1570761.950 5444147.406)
# ..                      ...                              ...
# 63                     Orán  POINT (2287195.989 7419561.720)
# 64     Rincon de los Sauces  POINT (1774214.302 5857484.503)
# 65             Tres Arroyos  POINT (2521222.679 5686315.521)
# 66            Villa Dolores  POINT (2148716.857 6445469.683)
# 67                   Zapala  POINT (1663510.934 5684371.893)
#
# [68 rows x 8 columns]

# %%
import pandas as pd 


portsFile=os.path.join('data','UpdatedPub150.csv')

infoseaports=pd.read_csv(portsFile)
#columns available (so many)
#infoseaports.columns.to_list()

# %%
#rename
infoseaports.rename(columns={'Main Port Name':'portName'},inplace=True)
#subset
infoseaports=infoseaports.loc[:,['portName', 'Country Code','Latitude', 'Longitude']]

# we have now
infoseaports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3824 entries, 0 to 3823
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   portName      3824 non-null   object
#  1   Country Code  3824 non-null   object
#  2   Latitude      3824 non-null   float64
#  3   Longitude     3824 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 119.6+ KB

# %%
#primero creo los puntos espaciales no proyectados
#1.spatial points (unprojected)
seaports=gpd.GeoDataFrame(data=infoseaports.copy(),
                           geometry=gpd.points_from_xy(infoseaports.Longitude,
                                                       infoseaports.Latitude), 
                          crs=4326)# notice it is unprojected

#2. subset: SUBSET
seaports_arg=seaports[seaports['Country Code']=='Argentina'].copy()

#3. reset indexes
seaports_arg.reset_index(drop=True, inplace=True)

#4. reprojecting
seaports_arg_22171=seaports_arg.to_crs(22171) # projected crs

# %%
base=medium_airport.plot(color='violet',marker="^")
seaports_arg_22171.plot(ax=base,alpha=0.5,markersize=3, color='red')
# Out:
# <Axes: >

# %%
distanceMatrixKM_sea_air=seaports_arg_22171.set_index('portName').geometry.apply\
(lambda g: medium_airport.set_index('name').geometry.distance(g)/1000)


distanceMatrixKM_sea_air
# Out:
# name                    Malvinas Argentinas Airport  \
# portName
# Puerto Madryn                           1366.768528
# Mar Del Plata                           2054.612633
# La Plata                                2385.171695
# Buenos Aires                            2396.589667
# Puerto Rosales                          1837.119805
# Puerto Deseado                           807.817097
# Puerto Belgrano                         1841.882928
# Puerto Santa Cruz                        537.749850
# Comodoro Rivadavia                      1001.386794
# Bahia Blanca                            1849.429614
# Concepcion Del Uruguay                  2629.553917
# Diamante                                2617.309206
# Concordia                               2752.775629
# Colon                                   2661.233332
# Quequen                                 1960.019739
# Parana                                  2658.174603
# Santa Fe                                2662.033793
# Ramallo                                 2476.040261
# Ushuaia                                    3.044313
# Rio Grande                               124.687930
# San Sebastian Bay                        187.289559
# Puerto Nacional                         1847.281096
# Villa Constitucion                      2496.229470
# Puerto Galvan                           1848.769968
# Puerto Gallegos                          362.162042
# Rosario                                 2520.762663
# San Nicolas                             2487.514964
# Puerto Ibicuy                           2467.082217
# Puerto Ingeniero White                  1847.611522
# Puerto San Martin                       2544.243639
# Villa Constitucion                      2488.935048
# Zarate                                  2434.691642
# Puerto San Julian                        616.926456
# San Lorenzo                             2540.587357
# San Blas                                1656.131262
# Campana                                 2429.182264
# San Pedro                               2469.781450
#
# name                    El Calafate - Commander Armando Tola International Airport  \
# portName
# Puerto Madryn                                                  994.191258
# Mar Del Plata                                                 1794.438217
# La Plata                                                      2079.731537
# Buenos Aires                                                  2080.069807
# Puerto Rosales                                                1491.006756
# Puerto Deseado                                                 531.014895
# Puerto Belgrano                                               1494.478742
# Puerto Santa Cruz                                              254.464856
# Comodoro Rivadavia                                             598.127468
# Bahia Blanca                                                  1497.272124
# Concepcion Del Uruguay                                        2297.133608
# Diamante                                                      2242.306851
# Concordia                                                     2415.464967
# Colon                                                         2328.401864
# Quequen                                                       1683.166434
# Parana                                                        2282.957784
# Rio Grande                        2441.284858     1657.277597
# San Sebastian Bay                 2378.819959     1582.870672
# Puerto Nacional                    809.097864      681.855619
# Villa Constitucion                 478.291924     1092.145944
# Puerto Galvan                      806.842695      680.535386
# Puerto Gallegos                   2212.475288     1408.229564
# Rosario                            442.695534     1090.423593
# San Nicolas                        490.559017     1092.656007
# Puerto Ibicuy                      599.191329     1145.993501
# Puerto Ingeniero White             809.602530      683.312375
# Puerto San Martin                  428.003826     1100.492955
# Villa Constitucion                 480.426027     1087.502448
# Zarate                             624.942298     1137.650610
# Puerto San Julian                 1946.492401     1165.726600
# San Lorenzo                        428.693055     1098.004342
# San Blas                           998.250024      699.974504
# Campana                            633.470575     1139.070100
# San Pedro                          536.588357     1107.425019
#
# [37 rows x 68 columns]

# %%
# distance between 'Malvinas Argentinas airport' and 'Ushuaia' in km
#elijo una fila, calculé las misnimas distancias y verifiqué que es un valor único 
distancia2puntos=medium_airport.iloc[0].geometry.distance(seaports_arg_22171.iloc[18].geometry)/1000
distancia2puntos
# Out:
# 3.044312931155478

# %%
base = argentinaMaps.plot(color='violet', edgecolor='black')
distancia2puntos.plot(ax=base)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 base = argentinaMaps.plot(color='violet', edgecolor='black')
#       2 distancia2puntos.plot(ax=base)
#
# AttributeError: 'str' object has no attribute 'plot'

# %% [markdown]
# ### Exercise 2
#
# <div class="alert-success">
#
# 1. Use **a map of points** and a **map of lines**. RIOS Y aeropuertos
#
# 2. Compute the **distance matrix for both maps**.
#
# 3. **Select one line of the distance matrix**, and **plot the closests and the farthest point to that line**.
#
#
# </div>

# %%
selectRiver=rivers[rivers.NAME.str.contains('Parana')]

# %%
distanceMatrixKM_riv_air=rivers.set_index('NAME').geometry.apply\
(lambda g: medium_airport.set_index('name').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)

# %%
systems=rivers.dissolve(by='SYSTEM')

# %%
systems.reset_index(drop=False,inplace=True)
systems.drop(columns='NAME',inplace=True)

# %%
distanceMatrixKM_sys_air=systems.set_index('SYSTEM').geometry.apply\
(lambda g: medium_airport.set_index('name').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)

distanceMatrixKM_sys_air
# Out:
# name    Aeropuerto Nacional de Formosa  Almirante Marco Andres Zar Airport  \
# SYSTEM
# Parana                      119.884028                         1192.210378
#
# name    Area De Material Airport  Aviador C. Campos Airport  \
# SYSTEM
# Parana                 357.38828                1248.443876
#
# name    Brigadier Antonio Parodi Airport  \
# SYSTEM
# Parana                       1454.725468
#
# name    Brigadier Mayor D Cesar Raul Ojeda Airport  \
# SYSTEM
# Parana                                  554.602025
#
# name    Capitan D Daniel Vazquez Airport  Capitan V A Almonacid Airport  \
# SYSTEM
# Parana                       1889.823063                     666.263284
#
# name    Catamarca Airport  Cataratas Del Iguazú International Airport  ...  \
# SYSTEM                                                                 ...
# Parana         620.609233                                   10.152287  ...
#
# name    Suboficial Ay Santiago Germano Airport  \
# SYSTEM
# Parana                              770.811267
#
# name    Teniente Benjamin Matienzo Airport  \
# SYSTEM
# Parana                          635.468721
#
# name    Termas de Río Hondo international Airport  Tres Arroyos Airport  \
# SYSTEM
# Parana                                 589.284828            535.858692
#
# name    Vicecomodoro Angel D. La Paz Aragonés Airport  Villa Dolores Airport  \
# SYSTEM
# Parana                                     520.414555             440.707637
#
# name    Villa Gesell Airport  Villa Reynolds Airport  Zapala Airport  \
# SYSTEM
# Parana              402.1483              476.424402     1106.447351
#
# name    Ástor Piazzola International Airport
# SYSTEM
# Parana                            465.674227
#
# [1 rows x 68 columns]

# %%
base=medium_airport.explore(color='violet',marker_kwds=dict(radius=10))
rivers[rivers.NAME.str.contains('Parana')].explore(m=base)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e55b0a0b5532126a098f570c2a64dba9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e55b0a0b5532126a098f570c2a64dba9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e55b0a0b5532126a098f570c2a64dba9 = L.map(
#                 &quot;map_e55b0a0b5532126a098f570c2a64dba9&quot;,
#                 {
#                     center: [-38.73235847361342, -63.26292637960533],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e55b0a0b5532126a098f570c2a64dba9);
#
#
#
#
#
#             var tile_layer_44547f703cf51bd1b36cbb5f513079be = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e55b0a0b5532126a098f570c2a64dba9);
#
#
#             map_e55b0a0b5532126a098f570c2a64dba9.fitBounds(
#                 [[-54.84385773217853, -72.05249784067556], [-22.620859215048306, -54.47335491853511]],
#                 {}
#             );
#
#
#         function geo_json_6af153539aed0202e5bebd6b7c789584_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;violet&quot;, &quot;fillColor&quot;: &quot;violet&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6af153539aed0202e5bebd6b7c789584_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6af153539aed0202e5bebd6b7c789584_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_6af153539aed0202e5bebd6b7c789584_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_6af153539aed0202e5bebd6b7c789584_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_6af153539aed0202e5bebd6b7c789584.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6af153539aed0202e5bebd6b7c789584_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6af153539aed0202e5bebd6b7c789584 = L.geoJson(null, {
#                 onEachFeature: geo_json_6af153539aed0202e5bebd6b7c789584_onEachFeature,
#
#                 style: geo_json_6af153539aed0202e5bebd6b7c789584_styler,
#                 pointToLayer: geo_json_6af153539aed0202e5bebd6b7c789584_pointToLayer
#         });
#
#         function geo_json_6af153539aed0202e5bebd6b7c789584_add (data) {
#             geo_json_6af153539aed0202e5bebd6b7c789584
#                 .addData(data)
#                 .addTo(map_e55b0a0b5532126a098f570c2a64dba9);
#         }
#             geo_json_6af153539aed0202e5bebd6b7c789584_add({&quot;bbox

# %%
mins=distanceMatrixKM_sys_air.idxmin(axis='columns') # same as axis=1
mins
# Out:
# SYSTEM
# Parana    General Urquiza Airport
# dtype: object

# %%
maxs=distanceMatrixKM_sys_air.idxmax(axis='columns') # same as axis=1
maxs
# Out:
# SYSTEM
# Parana    Malvinas Argentinas Airport
# dtype: object

# %%
base=systems.explore()
# the closest
medium_airport[medium_airport.name.isin(mins)].explore(m=base,color='orange',marker_kwds=dict(radius=10))
# the furthest
medium_airport[medium_airport.name.isin(maxs)].explore(m=base,color='green',marker_kwds=dict(radius=10))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b62dcf9a7b13f2e024bddc628bc2cbdc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b62dcf9a7b13f2e024bddc628bc2cbdc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b62dcf9a7b13f2e024bddc628bc2cbdc = L.map(
#                 &quot;map_b62dcf9a7b13f2e024bddc628bc2cbdc&quot;,
#                 {
#                     center: [-29.737025861392084, -57.46174621582031],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b62dcf9a7b13f2e024bddc628bc2cbdc);
#
#
#
#
#
#             var tile_layer_d901f8152257923b5ebb32382d467723 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b62dcf9a7b13f2e024bddc628bc2cbdc);
#
#
#             map_b62dcf9a7b13f2e024bddc628bc2cbdc.fitBounds(
#                 [[-33.88329962179349, -60.555683135986335], [-25.59075210099068, -54.3678092956543]],
#                 {}
#             );
#
#
#         function geo_json_4a93ee9e4e234acaddbb4eb4e322e177_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4a93ee9e4e234acaddbb4eb4e322e177_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4a93ee9e4e234acaddbb4eb4e322e177_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_4a93ee9e4e234acaddbb4eb4e322e177_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4a93ee9e4e234acaddbb4eb4e322e177_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_4a93ee9e4e234acaddbb4eb4e322e177.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4a93ee9e4e234acaddbb4eb4e322e177_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4a93ee9e4e234acaddbb4eb4e322e177 = L.geoJson(null, {
#                 onEachFeature: geo_json_4a93ee9e4e234acaddbb4eb4e322e177_onEachFeature,

# %% [markdown]
# ### Exercise 3
#
# <div class="alert-success">
#
# 1. **Create a set of points and a set of polygons**
#
# 2. Compute the **distance matrix for both sets**.
#
# 3. Select **one polygon** of the **distance matrix**, and plot the **closest** and the **farthest point to that polygon**.
#
# </div>

# %%
centroArgentina=country.centroid
centroArgentina
# Out:
# 0    POINT (2166251.918 6144387.372)
# dtype: geometry

# %%
centroidX=centroArgentina.x[0]
centroidY=centroArgentina.y[0]

# %%
municipalities.cx[:centroidX,centroidY:].unary_union
gpd.GeoDataFrame(index=[0],
                 crs=municipalities.crs,
                 geometry=[municipalities.cx[:centroidX,centroidY:].unary_union])
# Out:
#                                             geometry
# 0  POLYGON Z ((1837433.176 5990761.421 0.000, 183...

# %%
municipalities.cx[:centroidX,centroidY:].dissolve()
# Out:
#                                             geometry    ADM0_ES ADM0_PCODE  \
# 0  POLYGON Z ((1837433.176 5990761.421 0.000, 183...  Argentina         AR
#
#     ADM1_ES ADM1_PCODE ADM2_ES ADM2_REF ADM2_PCODE
# 0  La Rioja      AR046  Arauco   Arauco   AR046007

# %%
# you create
Argentina_topLeft=municipalities.cx[:centroidX,centroidY:].dissolve()

# %%
Argentina_topLeft['zone']='NW' # add column
Argentina_topLeft=Argentina_topLeft.loc[:,['ADM0_ES','zone','geometry']]

# %%
Argentina_bottomRight=municipalities.cx[centroidX:,:centroidY].dissolve()
Argentina_bottomRight['zone']='NE'
Argentina_bottomRight=Argentina_bottomRight.loc[:,['ADM0_ES','zone','geometry']]

# %%
uniondf=Argentina_topLeft.overlay(Argentina_bottomRight,how="union",keep_geom_type=True)

# %%
Argentina_topLeft_hull= gpd.GeoDataFrame(index=[0],
                                    crs=municipalities.crs,
                                    geometry=[Argentina_topLeft.unary_union.convex_hull])

# %%
Argentina_bottomRight_hull= gpd.GeoDataFrame(index=[0],
                                    crs=municipalities.crs,
                                    geometry=[Argentina_bottomRight.unary_union.convex_hull])

# %%
Argentina_topLeft_hull.overlay(Argentina_bottomRight_hull, how='union').plot()
# Out:
# <Axes: >

# %%
unionHulls=Argentina_topLeft_hull.overlay(Argentina_bottomRight_hull, how='union')

# %%
distanceMatrixKM_sysHull_air=uniondf.set_index('zone_1').geometry.apply\
(lambda g: medium_airport.set_index('name').geometry.distance(g)/1000).\
sort_index(axis=0).sort_index(axis=1)

distanceMatrixKM_sysHull_air
# Out:
# name    Aeropuerto Nacional de Formosa  Almirante Marco Andres Zar Airport  \
# zone_1
# NW                         1061.914513                          915.603615
# NW                          668.643776                          676.421211
# NaN                         864.040466                           40.588304
#
# name    Area De Material Airport  Aviador C. Campos Airport  \
# zone_1
# NW                    120.388629                 775.919374
# NW                      0.000000                 350.934955
# NaN                   166.442296                 484.340448
#
# name    Brigadier Antonio Parodi Airport  \
# zone_1
# NW                           1022.628357
# NW                            638.338745
# NaN                           424.952754
#
# name    Brigadier Mayor D Cesar Raul Ojeda Airport  \
# zone_1
# NW                                      137.828545
# NW                                        0.000000
# NaN                                     223.828012
#
# name    Capitan D Daniel Vazquez Airport  Capitan V A Almonacid Airport  \
# zone_1
# NW                           1608.876701                     533.019477
# NW                           1305.448261                       0.000000
# NaN                           732.106700                     644.895663
#
# name    Catamarca Airport  Cataratas Del Iguazú International Airport  ...  \
# zone_1                                                                 ...
# NW             599.531811                                 1325.258834  ...
# NW               0.000000                                 1059.836905  ...
# NaN            684.007425                                 1020.471661  ...
#
# name    Suboficial Ay Santiago Germano Airport  \
# zone_1
# NW                                  302.299633
# NW                                    0.000000
# NaN                                 305.021696
#
# name    Teniente Benjamin Matienzo Airport  \
# zone_1
# NW                              792.308372
# NW                                8.008485
# NaN                             857.911043
#
# name    Termas de Río Hondo international Airport  Tres Arroyos Airport  \
# zone_1
# NW                                     719.545739            469.261410
# NW                                       3.333550            505.066721
# NaN                                    782.994570              0.000000
#
# name    Vicecomodoro Angel D. La Paz Aragonés Airport  Villa Dolores Airport  \
# zone_1
# NW                                         694.069802             223.425317
# NW                                          67.164601               0.000000
# NaN                                        744.387723             318.382405
#
# name    Villa Gesell Airport  Villa Reynolds Airport  Zapala Airport  \
# zone_1
# NW                632.299642               35.042115      627.676779
# NW                728.510034                0.000000      202.843698
# NaN                 0.000000              143.612048      389.632328
#
# name    Ástor Piazzola International Airport
# zone_1
# NW                                622.279705
# NW                                713.116949
# NaN                                 0.000000
#
# [3 rows x 68 columns]

# %%
mins=distanceMatrixKM_sysHull_air.idxmin(axis="columns")
mins
# Out:
# zone_1
# NW        Villa Reynolds Airport
# NW      Area De Material Airport
# NaN    Comandante Espora Airport
# dtype: object

# %% [markdown]
# ## duda con esto

# %%
maxs=distanceMatrixKM_sysHull_air.idxmax(axis='columns') # same as axis=1
maxs
# Out:
# zone_1
# NW     Malvinas Argentinas Airport
# NW     Malvinas Argentinas Airport
# NaN    Malvinas Argentinas Airport
# dtype: object

# %%
base=unionHulls.explore()#qué tan distante está del poligono
                            
medium_airport[medium_airport.name.isin(mins)].explore(m=base,color='orange',marker_kwds=dict(radius=10))
medium_airport[medium_airport.name.isin(maxs)].explore(m=base,color='blue',marker_kwds=dict(radius=10))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46d2288eca05b62994d2980f995f4596 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46d2288eca05b62994d2980f995f4596&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46d2288eca05b62994d2980f995f4596 = L.map(
#                 &quot;map_46d2288eca05b62994d2980f995f4596&quot;,
#                 {
#                     center: [-32.330041339899196, -63.6243384386552],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_46d2288eca05b62994d2980f995f4596);
#
#
#
#
#
#             var tile_layer_8a671664ac8fe89cc1ab043afb0575ef = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46d2288eca05b62994d2980f995f4596);
#
#
#             map_46d2288eca05b62994d2980f995f4596.fitBounds(
#                 [[-42.87894788591273, -70.58368569338421], [-21.781134793885666, -56.6649911839262]],
#                 {}
#             );
#
#
#         function geo_json_e2f9aff659ae84acfe820c8992c2d72e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_e2f9aff659ae84acfe820c8992c2d72e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_e2f9aff659ae84acfe820c8992c2d72e_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_e2f9aff659ae84acfe820c8992c2d72e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_e2f9aff659ae84acfe820c8992c2d72e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_e2f9aff659ae84acfe820c8992c2d72e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_e2f9aff659ae84acfe820c8992c2d72e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_e2f9aff659ae84acfe820c8992c2d72e = L.geoJson(null, {
#                 onEachFeature: geo_json_e2f9aff659ae84acfe820c8992c2d72e_onEachFeature,

# %% [markdown]
# ### Exercise 4
#
# <div class="alert-success">
#
# 1. Create a **set of points** and a **set of lines**
#
# 2. Get the **buffer for the lines**, **select different values for the distance**.
#
# 3. **Keep the points** that are **within the buffer** (as in point 2, you **need to play with different distances until you show something interesting.
#
# </div>

# %%
distanceMatrixKM_riv_air

# %%
# getting a value (it can be any value)
distanceMatrixKM_riv_air.loc['Parana'].min()

# %%
minMts=distanceMatrixKM_riv_air.loc['Parana'].min()*1000

#the buffer is a polygon:
rivers[rivers.NAME=='Parana'].buffer(distance = minMts)

# %%
bufferAroundParana=rivers[rivers.NAME=='Parana'].buffer(distance = minMts)
bufferAsBase=bufferAroundParana.explore(color='orange')
rivers[rivers.NAME=='Parana'].explore(m=bufferAsBase,color='blue',style_kwds={'weight':0.5})

# %%
#set of points
small_airports=airports[airports['type']=='small_airport']

# plotting
rivers[rivers.NAME=='Parana'].explore(m=bufferAsBase,color='blue',style_kwds={'weight':0.5})
small_airports.explore(m=bufferAsBase,color='black')
#vemos que algunos pequeños aeropuertos caen dentro del buffer

# %%
riversWithinBuffer=small_airports.clip(mask=bufferAroundParana)

riversWithinBuffer

# %%
bufferAsBase=bufferAroundParana.explore(color='red')
rivers[rivers.NAME=='Parana'].explore(m=bufferAsBase,color='blue',style_kwds={'weight':0.5})
riversWithinBuffer.explore(m=bufferAsBase,color='black')

# %%
# minimum of all the minimum by row
distanceMatrixKM_riv_air.min(axis=1).min()

# %%
# using the previous value
minMinMts_5=2*distanceMatrixKM_riv_air.min(axis=1).min()*1000
#buffer de todoslos rios

allMinBuffer=rivers.buffer(distance = minMinMts_5).explore(color='orange')#minMinMts_5 esto es una medida técnica que he calculado
rivers.explore(m=allMinBuffer,color='blue',style_kwds={'weight':0.5})

# %%
# you see all the buffer polygons: #aqui se ven la cantidad de aeropuertos pequeños en la zona del buffer
riversAll_buf=rivers.buffer(distance = minMinMts_5)

# %%
allRiversWithinBuffs=small_airports.clip(riversAll_buf)
allRiversWithinBuffs

# %%
# simple
base=riversAll_buf.plot(color='violet')
allRiversWithinBuffs.plot(ax=base, color='blue', markersize=1)

# %%
# folium

base=riversAll_buf.explore(color='violet')
allRiversWithinBuffs.explore(m=base, color='blue')
